# %% [markdown]
# # TASK 1  IRIS FLOWER CLASSIFICATION

# %% [markdown]
# The Iris flower data set or Fisher’s Iris data set is one of the most famous multivariate data set used for testing various Machine Learning Algorithms.Iris flower has three species namely setosa, versicolor, and virginica, which differs according to their measurements. Now assume that you have the measurements of the iris flowers according to their species, and here your task is to train a machine learning model that can learn from the measurements of the iris species and classify them.

# %% [markdown]
# **Given the measurements of Sepal Width, Sepal length, Petal length and Petal width of all three categories.. We have to classify them based on their measurements.

# %% [markdown]
# # Steps
#
#    **1. Importing requried libraries
#      2. Loading of dataset
#      3. Display Summary Statistics
#      4. Data Visualization
#          4.1 Histograms(Uniariate analysis)
#          4.2 Scatter plots to visualize relation between variables(bivariate analysis)
#          4.3 Pair plots(Multivariate analysis)
#          4.4 Correlation matrix
#      5. Data Modelling
#          5.1 Train-Test-Split
#          5.2 Decision Tree classification(ID3 Classifier)
#          5.3 Confusion matrix
#          5.4 Model and accuracy sore
#      6. Prediction of species

# %% [markdown]
# # Importing requried libraries

# %%
#import requried libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
#loading dataset
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#Display first 8 and last 6 rows of dataset
print("First eight rows of dataset are: ")
print(df.head(8))
print("\n")
print("Last six rows of dataset are: ")
print(df.tail(6))
# Out:
# First eight rows of dataset are:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
#
#
# Last six rows of dataset are:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#Summary statistics of Iris dataset
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#To get no. of rows and columns in the dataset
print("Dimensions of dataset are: ",df.shape)
# Out:
# Dimensions of dataset are:  (150, 6)

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
import pandas as pd

# Sample data
data = {
    'species': ['setosa', 'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa']
}

# Create DataFrame
df = pd.DataFrame(data)

# Count the number of flowers in each species
print("No. of flowers in each species:", df['species'].value_counts())
# Out:
# No. of flowers in each species: setosa        3
# versicolor    2
# virginica     1
# Name: species, dtype: int64

# %%
#To get category of each type of species
print("No.of flowers in each species",df.value_counts("species"))
# Out:
# No.of flowers in each species species
# setosa        3
# versicolor    2
# virginica     1
# dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# We will use Matplotlib and Seaborn library for the data visualization.

# %%
#We will construct a count plot to see the count of each species
sns.countplot(x='species', data=df)
plt.show()

# %%
import pandas as pd

# Sample data
data = {
    'species': ['setosa', 'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa'],
    'sepal_length': [5.1, 7.0, 6.3, 5.4, 6.1, 5.2]
}

# Create DataFrame
df = pd.DataFrame(data)

# Print column names to verify
print(df.columns)

# Plot histogram of sepal_length
import matplotlib.pyplot as plt
plt.hist(df['sepal_length'], color='lavender')
plt.title("Histogram of Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()
# Out:
# Index(['species', 'sepal_length'], dtype='object')

# %%
print(df.columns)
# Out:
# Index(['species', 'sepal_length'], dtype='object')

# %%
print("No. of flowers in each species:", df['species'].value_counts())
# Out:
# No. of flowers in each species: setosa        3
# versicolor    2
# virginica     1
# Name: species, dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
plt.hist(df['sepal_length'],color='lavender')
plt.title("histogram")
plt.xlabel("Sepal Length")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
import pandas as pd

# Sample data
data = {
    'species': ['setosa', 'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa'],
    'petal_length': [1.4, 4.7, 5.1, 1.5, 4.5, 1.3]
}

# Create DataFrame
df = pd.DataFrame(data)

# Print column names to verify
print(df.columns)

# Plot histogram of petal_length
import matplotlib.pyplot as plt
plt.hist(df['petal_length'], color='black')
plt.title("Histogram of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()
# Out:
# Index(['species', 'petal_length'], dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
import matplotlib.pyplot as plt
plt.hist(df['petal_length'], color='green')
plt.title("Histogram of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'species': ['setosa', 'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa'],
    'petal_width': [0.2, 1.3, 2.3, 0.2, 1.0, 0.2]
}

# Create DataFrame
df = pd.DataFrame(data)

# Print column names to verify
print(df.columns)

# Strip any leading/trailing spaces from column names
df.columns = df.columns.str.strip()

# Use get method to avoid KeyError
petal_width = df.get('petal_width')
if petal_width is not None:
    plt.hist(petal_width, color='black')
    plt.title("Histogram of Petal Width")
    plt.xlabel("Petal Width")
    plt.ylabel("Frequency")
    plt.show()
else:
    print("Column 'petal_width' does not exist.")
# Out:
# Index(['species', 'petal_width'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'species': ['setosa', 'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa'],
    'sepal_length': [5.1, 7.0, 6.3, 4.9, 6.0, 5.4]
}

# Create DataFrame
df = pd.DataFrame(data)

# Print column names to verify
print(df.columns)

# Strip any leading/trailing spaces from column names
df.columns = df.columns.str.strip()

# Ensure DataFrame is loaded correctly
print(df.head())

# Use get method to avoid KeyError
sepal_length = df.get('sepal_length')
if sepal_length is not None:
    sns.swarmplot(x='species', y='sepal_length', data=df)
    plt.title("Swarm Plot of Sepal Length by Species")
    plt.xlabel("Species")
    plt.ylabel("Sepal Length")
    plt.show()
else:
    print("Column 'sepal_length' does not exist.")
# Out:
# Index(['species', 'sepal_length'], dtype='object')
#       species  sepal_length
# 0      setosa           5.1
# 1  versicolor           7.0
# 2   virginica           6.3
# 3      setosa           4.9
# 4  versicolor           6.0

# %% [markdown]
# # Relation between variables(attributes)

# %% [markdown]
# **We will see the relationship between the sepal length and sepal width and also between petal length and petal width. We shall construct various plots between different attributes of measurement to know about the relationship between them.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'species': ['setosa', 'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa'],
    'sepal_length': [5.1, 7.0, 6.3, 4.9, 6.0, 5.4],
    'sepal_width': [3.5, 3.2, 3.3, 3.1, 3.0, 3.4]
}

# Create DataFrame
df = pd.DataFrame(data)

# Print column names to verify
print(df.columns)

# Strip any leading/trailing spaces from column names
df.columns = df.columns.str.strip()

# Ensure DataFrame is loaded correctly
print(df.head())

# Use get method to avoid KeyError
sepal_width = df.get('sepal_width')
if sepal_width is not None:
    sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=df)
    plt.legend(bbox_to_anchor=(1, 1), loc=2)
    plt.title("Scatter Plot of Sepal Length vs Sepal Width by Species")
    plt.xlabel("Sepal Length")
    plt.ylabel("Sepal Width")
    plt.show()
else:
    print("Column 'sepal_width' does not exist.")
# Out:
# Index(['species', 'sepal_length', 'sepal_width'], dtype='object')
#       species  sepal_length  sepal_width
# 0      setosa           5.1          3.5
# 1  versicolor           7.0          3.2
# 2   virginica           6.3          3.3
# 3      setosa           4.9          3.1
# 4  versicolor           6.0          3.0

# %% [markdown]
# **From the above plot we can draw the following conclusions:
#     1. The species "Iris- Setosa" have larger sepal_width but smaller sepal_length when compared.
#     2. The species "Iris-versicolor" have smaller sepal_width and sepal_length when compared to other two and lies between.
#     3. The species "Iris-virginica" have larger sepal_length but smaller sepal_width when compared.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'species': ['setosa', 'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa'],
    'petal_length': [1.4, 4.7, 5.1, 1.5, 4.5, 1.3],
    'petal_width': [0.2, 1.3, 2.3, 0.2, 1.0, 0.2]
}

# Create DataFrame
df = pd.DataFrame(data)

# Print column names to verify
print(df.columns)

# Strip any leading/trailing spaces from column names
df.columns = df.columns.str.strip()

# Ensure DataFrame is loaded correctly
print(df.head())

# Use get method to avoid KeyError
petal_length = df.get('petal_length')
if petal_length is not None:
    sns.scatterplot(x='petal_length', y='petal_width', hue='species', data=df)
    plt.legend(bbox_to_anchor=(1, 1), loc=2)
    plt.title("Scatter Plot of Petal Length vs Petal Width by Species")
    plt.xlabel("Petal Length")
    plt.ylabel("Petal Width")
    plt.show()
else:
    print("Column 'petal_length' does not exist.")
# Out:
# Index(['species', 'petal_length', 'petal_width'], dtype='object')
#       species  petal_length  petal_width
# 0      setosa           1.4          0.2
# 1  versicolor           4.7          1.3
# 2   virginica           5.1          2.3
# 3      setosa           1.5          0.2
# 4  versicolor           4.5          1.0

# %% [markdown]
# **From the above plot we can draw some conclusions like:
#     1. The species "Iris-setosa" has smaller petal_width and petal length when compared.
#     2. The species "Iris-versicolor" have measurements middle of setosa and versicolor.
#     3. The species "Iris-virginica" have larger petal length and petal width when compared.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'species': ['setosa', 'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa'],
    'sepal_length': [5.1, 7.0, 6.3, 4.9, 6.0, 5.4],
    'petal_width': [0.2, 1.3, 2.3, 0.2, 1.0, 0.2]
}

# Create DataFrame
df = pd.DataFrame(data)

# Print column names to verify
print(df.columns)

# Strip any leading/trailing spaces from column names
df.columns = df.columns.str.strip()

# Ensure DataFrame is loaded correctly
print(df.head())

# Use get method to avoid KeyError
sepal_length = df.get('sepal_length')
if sepal_length is not None:
    sns.scatterplot(x='sepal_length', y='petal_width', hue='species', data=df)
    plt.legend(bbox_to_anchor=(1, 1), loc=2)
    plt.title("Scatter Plot of Sepal Length vs Petal Width by Species")
    plt.xlabel("Sepal Length")
    plt.ylabel("Petal Width")
    plt.show()
else:
    print("Column 'sepal_length' does not exist.")
# Out:
# Index(['species', 'sepal_length', 'petal_width'], dtype='object')
#       species  sepal_length  petal_width
# 0      setosa           5.1          0.2
# 1  versicolor           7.0          1.3
# 2   virginica           6.3          2.3
# 3      setosa           4.9          0.2
# 4  versicolor           6.0          1.0

# %%
#Multivariate analysis
#Pairplot which shows the pair-wise relation between every attributes
sns.pairplot(df,hue='species', height=2)

# %%
df.corr()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19620\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               sepal_length  petal_width
# sepal_length      1.000000     0.767159
# petal_width       0.767159     1.000000

# %%
# Visualizing the correlation between the columns using heatmap.
sns.heatmap(df.corr(), annot = True)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19620\3026344531.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)

# %% [markdown]
# # Data Modelling

# %% [markdown]
# Train-Test Split of data for evalutaing the performance of the machine learning algorithm.For splitting of dataset for training and testing we import train_test_split from sklearn.model_selection library.

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns = ['species'])
y = df['species']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.4)
y_test
# Out:
# 0       setosa
# 5       setosa
# 2    virginica
# Name: species, dtype: object

# %% [markdown]
# # Decision Tree : ID3 decision tree classifier
#
# ID3 stands for Iterative Dichotomiser 3 and is named such because the algorithm iteratively (repeatedly) dichotomizes(divides) features into two or more groups at each step. ID3 tree is mainly used for classification problems with nominal features only.

# %%
#Importing library foe decision classifier
from sklearn.tree import DecisionTreeClassifier
id3=DecisionTreeClassifier(criterion='entropy')
#Fit the data
k=id3.fit(x_train,y_train)
#predict the data
y_pred=id3.predict(x_test)
print(y_pred)
# Out:
# ['setosa' 'setosa' 'versicolor']

# %% [markdown]
# # Confusion Matrix
# **The confusion matrix is a matrix used to determine the performance of the classification models for a given set of test data. It can only be determined if the true values for test data are known. The matrix itself can be easily understood, but the related terminologies may be confusing. Since it shows the errors in the model performance in the form of a matrix, hence also known as an error matrix.

# %%
#Confusion matrix 
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm=confusion_matrix(y_pred,y_test)
plt.figure(figsize=(10,8))
sns.heatmap(cm,annot=True)
plt.xlabel('predicted-y')
plt.ylabel('actual-y')
plt.show()

# %% [markdown]
# Model accuracy score represents the model’s ability to correctly predict both the positives and negatives out of all the predictions. Mathematically, it represents the ratio of sum of true positive and true negatives out of all the predictions. **Accuracy Score = (TP + TN)/ (TP + FN + TN + FP)
#
# Accuracy score is calculated between predicted output value and test value Model score is calculated between output and input values of testing.

# %%
#Accuracy score and model score
print(classification_report(y_pred,y_test))
print('accuracy-score',accuracy_score(y_pred,y_test))
print('Model score',id3.score(x_test,y_test))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         2
#   versicolor       0.00      0.00      0.00         1
#    virginica       0.00      0.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.33      0.33         3
# weighted avg       0.67      0.67      0.67         3
#
# accuracy-score 0.6666666666666666
# Model score 0.6666666666666666
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Prediction of species
#
# Here we can classify the three types of species of Iris flowers.

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# Sample training data
X_train = np.array([[5.1, 3.5], [4.9, 3.0], [6.3, 3.3], [5.4, 3.4]])
y_train = np.array([0, 0, 1, 1])

# Train the model
id3 = DecisionTreeClassifier()
id3.fit(X_train, y_train)

# New data for prediction (ensure it has the same number of features as X_train)
X_new = np.array([[3, 2], [4.9, 2.2], [5.3, 2.5]])

# Prediction of the species
prediction = id3.predict(X_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: [0 0 1]
